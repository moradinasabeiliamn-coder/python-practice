# %%
shopping_list =[]

shopping_list.append(input("Please Enter your food item: "))
shopping_list.append(input("Please Enter your food item: "))
shopping_list.append(input("Please Enter your food item: "))

print(shopping_list)
# Out:
# ['31', '524154', '21344']
