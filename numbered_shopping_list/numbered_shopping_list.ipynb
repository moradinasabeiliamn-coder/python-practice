# %%
shopping_list = []

shopping_list.append(input("Please Enter your food item: "))
shopping_list.append(input("Please Enter your food item: "))
shopping_list.append(input("Please Enter your food item: "))


count = 0
for item in shopping_list :
    count = count +1 
    print(count, "." , item)
# Out:
# 1 . 5646
# 2 . 654654
# 3 . 65465
