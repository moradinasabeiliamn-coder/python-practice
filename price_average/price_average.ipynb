# %%
prices = []

prices.append(float(input("Enter price: ")))
prices.append(float(input("Enter price: ")))
prices.append(float(input("Enter price: ")))

Total = sum(prices)
Quantity = len(prices)

Avarage = Total / Quantity

print("Total:", Total)
print("Average:", Avarage)
